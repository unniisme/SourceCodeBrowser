# %%
# Mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Globals
SourceCodePath = "https://github.com/networkx/networkx"
DataStorePath = "/content/drive/MyDrive/NLP-Project/data"
ModelStorePath = "/content/drive/MyDrive/NLP-Project/finetuned-models"
PretrainedPath = "/content/drive/MyDrive/NLP-Project/pretrained"

# %%
# Wrapper classes

from transformers import RobertaTokenizer, T5ForConditionalGeneration, AutoTokenizer
import torch
import logging

pretrained = lambda lang : f"{PretrainedPath}/summarize_{lang}_codet5_base.bin"

class T5Model:
    """
    Loads the codeT5 base multilingual summarization model.
    Additionally, if a language name is provided, checks if pretrained weights for that langauges is available and loads it.
    """

    def __init__(self, lang = None):
        self.tokenizer = RobertaTokenizer.from_pretrained('Salesforce/codet5-base')
        self.model = T5ForConditionalGeneration.from_pretrained('Salesforce/codet5-base-multi-sum')

        logging.info("[T5Model] Loaded Salesforce/codet5-base-multi-sum and tokenizer")

        if lang != None:
            try:
                self.model.load_state_dict(torch.load(pretrained(lang)))
                logging.info(f"Loaded model for {lang}")
            except Exception as e:
                logging.error(e)

    def predict(self,text):
        logging.debug(f"[{self.__class__.__name__}] Predicting for sequence: \n{text}")

        input_ids = self.tokenizer(text, return_tensors="pt").input_ids

        generated_ids = self.model.generate(input_ids, max_length=512)
        return self.tokenizer.decode(generated_ids[0], skip_special_tokens=True)


class T5_plus(T5Model):
    """
    Load the T5_plus model
    """

    def __init__(self):
        checkpoint = "Salesforce/codet5p-220m-py"
        self.tokenizer = AutoTokenizer.from_pretrained(checkpoint)
        self.model = T5ForConditionalGeneration.from_pretrained(checkpoint)

        logging.info(f"[T5_plus] Loaded model and tokenizer at {checkpoint}")

# %%
class T5Model_Pretrained(T5Model):
    """
    Load a T5Model from a checkpoint
    """
    def __init__(self, model_path):
        self.tokenizer = RobertaTokenizer.from_pretrained(model_path)
        self.model = T5ForConditionalGeneration.from_pretrained(model_path)

        logging.info(f"[T5Model_Pretrained] Loaded model and tokenizer at {model_path}")

# %% [markdown]
# # Task 1: Docstring generation

# %% [markdown]
# Training the base codeT5 model on the netowrkx dataset

# %%
import torch

import json
import logging
import os
import sys
import time

FORMAT = "[%(levelname)-8s][%(asctime)s][%(filename)s:%(lineno)s - %(funcName)13s()] %(message)s"
logging.basicConfig(format=FORMAT, stream=sys.stdout, encoding='utf-8', level=logging.DEBUG)


def TokenizePair(data_pair, tokenizer):

    input_text = f"Docstring Gen: {data_pair['code']} </s>"
    target_text = f"{data_pair['docstring']} </s>"

    encoded = tokenizer(
        input_text,
        # pad_to_max_length=True,
        padding='max_length',
        truncation=True,
        max_length=512,
        return_tensors='pt'
    )

    decoded = tokenizer(
        target_text,
        # pad_to_max_length=True,
        padding='max_length',
        truncation=True,
        max_length=512,
        return_tensors='pt'
    )

    input_ids = encoded.input_ids.flatten()
    output_ids = decoded.input_ids.flatten()

    return {
        'input_ids': input_ids,
        'labels' : output_ids
    }

# Loading dataset
class CustomIterableDataset(torch.utils.data.IterableDataset):
    def __init__(self, file_paths, tokenizer):
        self.file_paths = file_paths
        self.tokenizer = tokenizer

    def __iter__(self):
        for file_path in self.file_paths:
            logging.debug(f"loading {file_path}")
            with open(file_path, 'r') as file:
                data = json.load(file)
                for data_pair in data:
                    tokenizedPair = TokenizePair(data_pair, self.tokenizer)
                    tokenizedPair["file"] = file_path
                    yield tokenizedPair


logging.info("Loading model")
t5model = T5Model()

logging.info("Defining dataset")
jsons = [f"{DataStorePath}/{f}" for f in os.listdir(DataStorePath)]
train_dataset = CustomIterableDataset(jsons, t5model.tokenizer)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=1)


model = t5model.model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

logging.info("Training")
# Fine-tuning the model
num_epochs = 10
for epoch in range(num_epochs):
    for batch in train_loader:
      try:
        input_ids = batch['input_ids'].to(device)
        labels = batch['labels'].to(device)

        optimizer.zero_grad()

        outputs = model(
            input_ids=input_ids,
            labels=labels
        )

        loss = outputs.loss
        loss.backward()
        optimizer.step()

        print(f"File {batch['file']} Loss : {loss.item()}")
        logging.debug(f"File {batch['file']} Loss : {loss.item()}")
      except Exception as e:
        logging.error(e)
      except:
        logging.error("Didn't catch that")

    print(f"Epoch {epoch+1}/{num_epochs} | Loss: {loss.item()}")
    logging.info(f"Epoch {epoch+1}/{num_epochs} | Loss: {loss.item()}")

    timestamp = time.time()
    model.save_pretrained(f"{ModelStorePath}/fine_tuned_model.{timestamp}")
    t5model.tokenizer.save_pretrained(f"{ModelStorePath}/fine_tuned_model.{timestamp}")

logging.info("Saving")
# Save the model after training
model.save_pretrained(f"{ModelStorePath}/fine_tuned_model")
t5model.tokenizer.save_pretrained(f"{ModelStorePath}/fine_tuned_model")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.06389087438583374
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.08874723315238953
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.00207601860165596
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.006429915316402912
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.003044565673917532
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.005995127372443676
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0015464125899598002
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.004033270757645369
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.035808417946100235
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.013969729654490948
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.010015328414738178
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.017546793445944786
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.005373458843678236
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0006189647247083485
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.015207543969154358
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.02178388461470604
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.016907043755054474
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0014096178347244859
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.038126636296510696
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.004351524636149406
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0034024096094071865
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0036683734506368637
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0006161892088130116
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 9.549714741297066e-05
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.00011323713988531381
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.010762973688542843
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.03514350205659866
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.008360018022358418
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0020473322365432978
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.001249204738996923
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.013551047071814537
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.01080442313104868
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.008773498237133026
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 7.208254100987688e-05
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0018798921955749393
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0066948323510587215
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0020741047337651253
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.008454891853034496
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.005729895085096359
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0030999004375189543
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0010370854288339615
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.000516686646733433
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.002445876831188798
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.016381410881876945
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.012362358160316944
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.00513475202023983
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.007112349849194288
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.005908609833568335
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0027884149458259344
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.005700856912881136
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.004678828176110983
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.007037569303065538
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.005633316468447447
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0016948818229138851
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0009208085248246789
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.002311369637027383
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0038566733710467815
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.004501440096646547
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0025256613735109568
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.00182258989661932
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0010464199585840106
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.004660067614167929
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.005034292582422495
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0004213463980704546
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.00042647062218748033
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.00078874098835513
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0009526733192615211
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.010352106764912605
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.008325120434165001
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.004855849780142307
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.004073127638548613
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0052939001470804214
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.001936348620802164
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.011770143173635006
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.013768019154667854
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.006716840900480747
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.005285527091473341
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.004936525598168373
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.01083894819021225
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.00912102684378624
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.01762789487838745
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.007288810331374407
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.012912051752209663
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.000667555199470371
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.011092989705502987
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.005387230310589075
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0059519303031265736
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.00997319258749485
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.021993465721607208
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.00841756071895361
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0012950657401233912
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.016900839284062386
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.022381825372576714
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.002419006312265992
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0044105928391218185
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.0007639503455720842
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0.013243841007351875
# File ['/content/drive/MyDrive/NLP-Project/data/algorithms.json'] Loss : 0
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.023792169988155365
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.1594305783510208
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.026315968483686447
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0553419403731823
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.019198765978217125
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.08084654062986374
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.03022843413054943
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.019768593832850456
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.1108131930232048
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.10933345556259155
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.04571432247757912
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.056068263947963715
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.05504531413316727
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.04976007714867592
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 7.347913924604654e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00014605719479732215
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.03750016540288925
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.013324175961315632
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00021607497183140367
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00022514785814564675
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0419127382338047
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.12526462972164154
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.011549684219062328
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0016971927834674716
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.07741685211658478
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.10809523612260818
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.03723688796162605
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.10023792088031769
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.16648341715335846
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.10991790890693665
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.06968609243631363
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 7.610818283865228e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00021210216800682247
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00419717887416482
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.03572558984160423
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.02230439893901348
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.10587042570114136
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.06182611733675003
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.06936530768871307
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0030983302276581526
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.030381815508008003
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.012640365399420261
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.001143687404692173
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0027852284256368876
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00022740876011084765
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 4.675277159549296e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 5.736647653975524e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0002769249549601227
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0010789725929498672
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.004850669298321009
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0002758913324214518
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0003447696508374065
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0009433756349608302
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.012183966115117073
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.03827393800020218
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 3.1918818422127515e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00013677972310688347
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00028939262847416103
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0005565695464611053
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 6.062502507120371e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00010217632370768115
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 9.55563664319925e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 4.1169318137690425e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00013091712025925517
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00032749256934039295
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.008091401308774948
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 7.635683141415939e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 9.333515481557697e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00011587211338337511
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0005191750242374837
# Epoch 10/10 | Loss: 0.0005191750242374837
# ('/content/drive/MyDrive/NLP-Project/finetuned-models/fine_tuned_model/tokenizer_config.json',
#  '/content/drive/MyDrive/NLP-Project/finetuned-models/fine_tuned_model/special_tokens_map.json',
#  '/content/drive/MyDrive/NLP-Project/finetuned-models/fine_tuned_model/vocab.json',
#  '/content/drive/MyDrive/NLP-Project/finetuned-models/fine_tuned_model/merges.txt',
#  '/content/drive/MyDrive/NLP-Project/finetuned-models/fine_tuned_model/added_tokens.json')

# %% [markdown]
# Training the fine tuned codeT5 (fine tuned on the downstream task of generating python docstrings using function names) model on the networkx dataset

# %%
import torch

import json
import logging
import os
import sys
import time

FORMAT = "[%(levelname)-8s][%(asctime)s][%(filename)s:%(lineno)s - %(funcName)13s()] %(message)s"
logging.basicConfig(format=FORMAT, stream=sys.stdout, encoding='utf-8', level=logging.DEBUG)
modelStorePath = ModelStorePath + "/python"

def TokenizePair(data_pair, tokenizer):

    input_text = f"Docstring Gen: {data_pair['code']} </s>"
    target_text = f"{data_pair['docstring']} </s>"

    encoded = tokenizer(
        input_text,
        # pad_to_max_length=True,
        padding='max_length',
        truncation=True,
        max_length=512,
        return_tensors='pt'
    )

    decoded = tokenizer(
        target_text,
        # pad_to_max_length=True,
        padding='max_length',
        truncation=True,
        max_length=512,
        return_tensors='pt'
    )

    input_ids = encoded.input_ids.flatten()
    output_ids = decoded.input_ids.flatten()

    return {
        'input_ids': input_ids,
        'labels' : output_ids
    }

# Loading dataset
class CustomIterableDataset(torch.utils.data.IterableDataset):
    def __init__(self, file_paths, tokenizer):
        self.file_paths = file_paths
        self.tokenizer = tokenizer

    def __iter__(self):
        for file_path in self.file_paths:
            logging.debug(f"loading {file_path}")
            with open(file_path, 'r') as file:
                data = json.load(file)
                for data_pair in data:
                    tokenizedPair = TokenizePair(data_pair, self.tokenizer)
                    tokenizedPair["file"] = file_path
                    yield tokenizedPair


logging.info("Loading python downstream model")
t5model = T5Model('python') # This is the downstream model for python summarization

logging.info("Defining dataset")
jsons = [f"{DataStorePath}/{f}" for f in os.listdir(DataStorePath)]
train_dataset = CustomIterableDataset(jsons, t5model.tokenizer)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=1)


model = t5model.model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

logging.info("Training")
# Fine-tuning the model
num_epochs = 10
for epoch in range(num_epochs):
    for batch in train_loader:
      try:
        input_ids = batch['input_ids'].to(device)
        labels = batch['labels'].to(device)

        optimizer.zero_grad()

        outputs = model(
            input_ids=input_ids,
            labels=labels
        )

        loss = outputs.loss
        loss.backward()
        optimizer.step()

        print(f"File {batch['file']} Loss : {loss.item()}")
        logging.debug(f"File {batch['file']} Loss : {loss.item()}")
      except Exception as e:
        logging.error(e)
      except:
        logging.error("Didn't catch that")

    print(f"Epoch {epoch+1}/{num_epochs} | Loss: {loss.item()}")
    logging.info(f"Epoch {epoch+1}/{num_epochs} | Loss: {loss.item()}")

    timestamp = time.time()
    model.save_pretrained(f"{modelStorePath}/fine_tuned_model.{timestamp}")
    t5model.tokenizer.save_pretrained(f"{modelStorePath}/fine_tuned_model.{timestamp}")

logging.info("Saving")
# Save the model after training
model.save_pretrained(f"{modelStorePath}/fine_tuned_model")
t5model.tokenizer.save_pretrained(f"{modelStorePath}/fine_tuned_model")
# Out:
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.0030279899947345257
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.0008142722072079778
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.1275753527879715
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.003021589247509837
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.04297548532485962
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.017853016033768654
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.02168833650648594
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.05207350105047226
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.0005080531118437648
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.00045068396138958633
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.04355548322200775
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.0810130164027214
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.18605655431747437
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.0377180390059948
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.3805951178073883
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.1521325707435608
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.02120232582092285
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.01793861575424671
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.04772036150097847
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.08257769048213959
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.1216309666633606
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.02776893600821495
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.03737303614616394
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.08031374216079712
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.142676442861557
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.011944076977670193
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.004727120976895094
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.007203646469861269
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.0071183196268975735
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.013759088702499866
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.0008809586870484054
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.00031811310327611864
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.00024233543081209064
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.0005056068766862154
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.0014601674629375339
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.0026501247193664312
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.0013357667485252023
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 6.343423592625186e-05
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.00013482989743351936
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 5.863421756657772e-05
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.0005754696321673691
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 5.3408381063491106e-05
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.0011659790761768818
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.0011867642169818282
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 6.557305459864438e-05
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 3.853495582006872e-05
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.00023960554972290993
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 1.2185427294753026e-05
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 6.342241249512881e-05
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.001033583888784051
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.008699508383870125
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.002928190864622593
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.010500726290047169
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.002808663761243224
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.031845822930336
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.12116556614637375
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.21333707869052887
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.07749862968921661
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.16452747583389282
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.00847259908914566
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.025872228667140007
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.017296839505434036
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.04140033200383186
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.028845753520727158
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.07387250661849976
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.15454688668251038
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.011307543143630028
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.009901458397507668
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.10791607201099396
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.001213362906128168
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.005318078678101301
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.0023351230192929506
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.015698330476880074
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.025003425776958466
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.0004841824120376259
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.00248355558142066
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.0004357866710051894
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.003976316191256046
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.00020046383724547923
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.002981735859066248
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.003981269430369139
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.0002782494993880391
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.0002331067225895822
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.002049452858045697
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.0006159494514577091
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.0005817762576043606
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.000604996457695961
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.0012186075327917933
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.00012110552779631689
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.0314958393573761
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.008607501164078712
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.004499897360801697
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.03394697979092598
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.008818822912871838
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.008725584484636784
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.01115454826503992
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.002656554104760289
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0010178557131439447
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00011431608436396345
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.007441650610417128
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.026430882513523102
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.016386672854423523
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.025457866489887238
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.034102488309144974
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.02146703377366066
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.09387630224227905
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.06617478281259537
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.030159998685121536
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.04464515298604965
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.17544612288475037
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.02524307370185852
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.13156773149967194
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.011924914084374905
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.01583407260477543
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.02296602353453636
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.01014686282724142
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.13162250816822052
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.16982798278331757
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.07060679793357849
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.034551847726106644
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0707949846982956
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.048963528126478195
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 3.9949813071871176e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 9.568973473506048e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.03885703533887863
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.011920882388949394
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0005109173362143338
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0007795605342835188
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.09639754891395569
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.05220674350857735
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.008589128963649273
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.001969121163710952
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.05749918520450592
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.1584196537733078
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.03739839792251587
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.12284963577985764
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.2094280868768692
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.15392756462097168
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.03537443280220032
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 4.5223714550957084e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00014863711840007454
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.014207018539309502
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.01304609328508377
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.012630435638129711
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.12040989100933075
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.05408826097846031
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.040333449840545654
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0015917276032269
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.01630641147494316
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.005547144915908575
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0011509883916005492
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0018872632645070553
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0020014196634292603
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.009632948786020279
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0008420706726610661
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 9.035445691552013e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0014343110378831625
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.017298700287938118
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.001355073880404234
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0007760825101286173
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00200576800853014
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.018784668296575546
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.03890089690685272
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 7.731822552159429e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 3.6936369724571705e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00016277309623546898
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0001305366022279486
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 5.632573083858006e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 9.946215868694708e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 8.31508295959793e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00010386387293692678
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00018857500981539488
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.00023534093634225428
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.01505272462964058
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 4.627671660273336e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 8.046557195484638e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 6.018590647727251e-05
# File ['/content/drive/MyDrive/NLP-Project/data/classes.json'] Loss : 0.0016548061976209283
# Epoch 2/2 | Loss: 0.0016548061976209283
# ('/content/drive/MyDrive/NLP-Project/finetuned-models/python/fine_tuned_model/tokenizer_config.json',
#  '/content/drive/MyDrive/NLP-Project/finetuned-models/python/fine_tuned_model/special_tokens_map.json',
#  '/content/drive/MyDrive/NLP-Project/finetuned-models/python/fine_tuned_model/vocab.json',
#  '/content/drive/MyDrive/NLP-Project/finetuned-models/python/fine_tuned_model/merges.txt',
#  '/content/drive/MyDrive/NLP-Project/finetuned-models/python/fine_tuned_model/added_tokens.json')

# %%
## Testing using examples

t5_python_model = T5Model('python')
finalModel_base = T5Model_Pretrained(ModelStorePath + "/fine_tuned_model")
finalModel_python = T5Model_Pretrained(ModelStorePath + "/python/fine_tuned_model")

inp = "@not_implemented_for('multigraph')\n@nx._dispatch\ndef peak_number(G, cores=None):\n    if nx.number_of_selfloops(G) > 0:\n        msg = 'Input graph has self loops which is not permitted; Consider using G.remove_edges_from(nx.selfloop_edges(G)).'\n        raise NetworkXError(msg)\n    if cores is None:\n        cores = nx.core_number(G)\n    H = G.copy()\n    peak_number = {}\n    while H.nodes():\n        core_degeneracy = nx.k_core(H, core_number=cores)\n        peak_number.update({node: cores[node] for node in core_degeneracy})\n        H.remove_nodes_from(core_degeneracy.nodes())\n        cores = nx.core_number(H)\n    return peak_number"
out_t5 = t5_python_model.predict("Docstring Gen: " + inp)
out_base = finalModel_base.predict("Docstring Gen: " + inp)
out_python = finalModel_python.predict("Docstring Gen: " + inp)

print(out_t5)
print("---------------------------------")
print("---------------------------------")
print("---------------------------------")
print(out_base)
print("--------------------------------")
print("--------------------------------")
print("--------------------------------")
print(out_python)
# Out:
# ERROR:root:Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.
# Compute peak number of nodes in a network.
# ---------------------------------
# ---------------------------------
# ---------------------------------
# Returns the peak number of each node.
#
# The peak number of a node in a graph is
#
# .. math::
#
#    A connected graph with no self loops should
# be computed by adding the self loops.
#
# Parameters
# ----------
# G : NetworkX graph
#
# cores : dictionary (default=None)
#     Precomputed core numbers for the graph. If None, it will be
#     computed.
#
# Returns
# -------
# Pal number
#     The peak number of all nodes in the graph.
#
# Raises
# ------
# NetworkXError
#     If `G` is a multigraph or if
#     `cores` is None.
#
#
# --------------------------------
# --------------------------------
# --------------------------------
# Returns the number of edges that disconnects G.
#
# A number of edges is a subset of the nodes of the graph which consists
# of self loops. A self loop consists of self loops on either the left or right,
# other nodes of the graph. A self loop consists of
# the nodes of the graph and the edges of the graph. A self loop
# or selfloop edges are called a self-loop if the input graph has self loops.
#
# The input graph is a self-loop if the input graph is a self-loop, and that graph is
# also the self-loop.
#
# The algorithm repeatedly sets the value of the k-core's k-core.
#
# The algorithm repeatedly sets the value of the k-core's k-core.
#
# The input graph is undirected, and so on.
#
# Parameters
# ----------
# G : NetworkX Graph
#    An undirected NetworkX graph.
#
# cores : dict, optional (default=None)
#    The core numbers for the generated graph.
#    If None, the core numbers are generated from the input graph.
#
# Returns
# -------
# n
#     The number of edges that u-core.
#
# Raises
# ------
# NetworkXError
#     If `G` is a multigraph.

# %% [markdown]
# # Task 2: Code generation from Docstring

# %%
import torch

import json
import logging
import os
import sys
import time

FORMAT = "[%(levelname)-8s][%(asctime)s][%(filename)s:%(lineno)s - %(funcName)13s()] %(message)s"
logging.basicConfig(format=FORMAT, stream=sys.stdout, encoding='utf-8', level=logging.DEBUG)
modelStorePath = ModelStorePath + "/generation-from-docstring"


def TokenizePair(data_pair, tokenizer):

    input_text = f"Code Gen: {data_pair['docstring']} </s>"
    target_text = f"{data_pair['code']} </s>"

    encoded = tokenizer(
        input_text,
        # pad_to_max_length=True,
        padding='max_length',
        truncation=True,
        max_length=512,
        return_tensors='pt'
    )

    decoded = tokenizer(
        target_text,
        # pad_to_max_length=True,
        padding='max_length',
        truncation=True,
        max_length=512,
        return_tensors='pt'
    )

    input_ids = encoded.input_ids.flatten()
    output_ids = decoded.input_ids.flatten()

    return {
        'input_ids': input_ids,
        'labels' : output_ids
    }

# Loading dataset
class CustomIterableDataset(torch.utils.data.IterableDataset):
    def __init__(self, file_paths, tokenizer):
        self.file_paths = file_paths
        self.tokenizer = tokenizer

    def __iter__(self):
        for file_path in self.file_paths:
            logging.debug(f"loading {file_path}")
            with open(file_path, 'r') as file:
                data = json.load(file)
                for data_pair in data:
                    tokenizedPair = TokenizePair(data_pair, self.tokenizer)
                    tokenizedPair["file"] = file_path
                    yield tokenizedPair


logging.info("Loading model")
t5model = T5Model()

logging.info("Defining dataset")
jsons = [f"{DataStorePath}/{f}" for f in os.listdir(DataStorePath)]
train_dataset = CustomIterableDataset(jsons, t5model.tokenizer)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=1)


model = t5model.model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

logging.info("Training")
# Fine-tuning the model
num_epochs = 5
for epoch in range(num_epochs):
    for batch in train_loader:
      try:
        input_ids = batch['input_ids'].to(device)
        labels = batch['labels'].to(device)

        optimizer.zero_grad()

        outputs = model(
            input_ids=input_ids,
            labels=labels
        )

        loss = outputs.loss
        loss.backward()
        optimizer.step()

        print(f"File {batch['file']} Loss : {loss.item()}")
        logging.debug(f"File {batch['file']} Loss : {loss.item()}")
      except Exception as e:
        logging.error(e)
      except:
        logging.error("Didn't catch that")

    print(f"Epoch {epoch+1}/{num_epochs} | Loss: {loss.item()}")
    logging.info(f"Epoch {epoch+1}/{num_epochs} | Loss: {loss.item()}")

    timestamp = time.time()
    model.save_pretrained(f"{modelStorePath}/fine_tuned_model.{timestamp}")
    t5model.tokenizer.save_pretrained(f"{modelStorePath}/fine_tuned_model.{timestamp}")

logging.info("Saving")
# Save the model after training
model.save_pretrained(f"{modelStorePath}/fine_tuned_model")
t5model.tokenizer.save_pretrained(f"{modelStorePath}/fine_tuned_model")
# Out:
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 3.406301259994507
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 1.4591442346572876
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 5.467596054077148
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 5.8901872634887695
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 2.303309679031372
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 1.7118998765945435
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 2.641272783279419
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.7780472636222839
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 1.1538182497024536
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.4273897409439087
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.4280437231063843
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 1.3444536924362183
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 2.399918556213379
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 2.2058045864105225
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 1.5304361581802368
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 2.4577412605285645
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.24662278592586517
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.7320005297660828
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 1.4667739868164062
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.34893351793289185
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 1.3237180709838867
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.9554692506790161
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 2.0826940536499023
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.4318549335002899
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.43463844060897827
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.2295522838830948
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.20998069643974304
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.14829355478286743
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.24777233600616455
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.16763266921043396
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.5720919370651245
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.505674421787262
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.44377416372299194
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.8655560612678528
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 1.3761910200119019
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 3.1692843437194824
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 1.3453372716903687
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 2.8934526443481445
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 2.2929792404174805
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 1.1187052726745605
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 1.834700345993042
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.7911433577537537
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.8279070258140564
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 1.0886119604110718
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.7027056813240051
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.7856602668762207
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.25382038950920105
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.3248295187950134
# File ['/content/drive/MyDrive/NLP-Project/data/linalg.json'] Loss : 0.49618402123451233
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.36734887957572937
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 3.3893330097198486
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 1.2700566053390503
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 3.5226807594299316
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.16511237621307373
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 1.6115953922271729
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.714041531085968
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.702300488948822
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.09536516666412354
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.09117787331342697
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 2.034947395324707
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.3720026910305023
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 1.3168548345565796
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.1600119173526764
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.40299105644226074
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 1.426815152168274
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 3.2165632247924805
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 2.379016399383545
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.46371158957481384
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.35211706161499023
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.05971071869134903
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.04993421584367752
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.04878188669681549
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.04659640043973923
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.03886616230010986
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.05408310145139694
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.047184932976961136
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.023747123777866364
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.03258700296282768
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.07110726088285446
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.4772705137729645
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.8994962573051453
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.2690734565258026
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.08707741647958755
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.37304168939590454
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.3616466820240021
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.4798915684223175
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.3697178363800049
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.3707420229911804
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.4188847541809082
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 1.3606154918670654
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.54269939661026
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.35727623105049133
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.9120633602142334
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.15783019363880157
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.637627363204956
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.4494720995426178
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.13963443040847778
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.3395550549030304
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.1618332862854004
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.49698400497436523
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.7040032148361206
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.28718826174736023
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 1.723520278930664
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.15992087125778198
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.3114078640937805
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.8956922888755798
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.23068170249462128
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.6459375619888306
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.37574297189712524
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.2774149179458618
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.1599648892879486
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.08003858476877213
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.18468034267425537
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.3452834486961365
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.04891807958483696
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.12864135205745697
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.39900389313697815
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.23141077160835266
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.4568916857242584
# File ['/content/drive/MyDrive/NLP-Project/data/utils.json'] Loss : 0.292483389377594
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.7155423164367676
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.6738706231117249
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 1.2065967321395874
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.2788200080394745
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.6501524448394775
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.18575969338417053
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 2.5546910762786865
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.31008824706077576
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.1476246565580368
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.22678466141223907
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.18133491277694702
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.18086589872837067
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.2696952223777771
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 1.2745739221572876
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.4216245114803314
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.9438340663909912
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.3177940547466278
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.5282701849937439
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.7857959866523743
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 3.4068055152893066
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 2.1496105194091797
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 2.4833498001098633
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.10703270882368088
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.9884697794914246
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 1.799359679222107
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.32209089398384094
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.20467594265937805
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.08599170297384262
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.3002934157848358
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.41977450251579285
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.5339934825897217
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.15762241184711456
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.19868968427181244
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.3170635402202606
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.11323539167642593
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.8232003450393677
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.6304253935813904
# File ['/content/drive/MyDrive/NLP-Project/data/readwrite.json'] Loss : 0.15511906147003174

# %%
## Testing using examples

t5_python_model = T5Model()
finalModel_base = T5Model_Pretrained(ModelStorePath + "/generation-from-docstring/fine_tuned_model.1714661974.8295977")

inp = "Returns the peak number for each vertex.\n\nA k-peak of a graph is a maximal subgraph that contains nodes of degree k or more within each other.\n\nParameters\n----------\nG : NetworkX graph\n   A graph or directed graph\ncores : dictionary, optional\n  Precomputed core numbers for the graph G.\n\nReturns\n-------\npeak_number : dictionary\n   A dictionary keyed by node to the peak number.\n\nRaises\n------\nNetworkXError\n    The k-peak is not implemented for graphs with self loops\n    or parallel edges.\n\n"
out_t5 = t5_python_model.predict("Generate Python: " + inp)
out_base = finalModel_base.predict("Code Gen: " + inp)

print(out_t5)
print("---------------------------------")
print("---------------------------------")
print("---------------------------------")
print(out_base)
print("--------------------------------")
print("--------------------------------")
print("--------------------------------")
# Out:
# Returns the peak number for each node in a graph.
# ---------------------------------
# ---------------------------------
# ---------------------------------
# def k_peak(G, cores=None):
#     if G.is_directed()!= nx.is_directed():
#         msg = 'Input graph is not directed and is not strongly connected.'
#         raise NetworkXError(msg)
#     if G.is_directed()!= nx.is_directed()!= nx.is_directed()!= nx.is_directed()!= nx.is_directed()!= nx.is_directed()!= nx.is_connected(G):
#         msg = 'Input graph is not connected.'
#         raise NetworkXError(msg)
#     return {v: 0 for v in G.nodes() if v in G.degree() > 0}
# --------------------------------
# --------------------------------
# --------------------------------

# %% [markdown]
# # Task 3: Next line prediction

# %% [markdown]
# Training the base T5 model on the the downstream task of next line prediction

# %%
import torch

import json
import logging
import os
import sys
import time

FORMAT = "[%(levelname)-8s][%(asctime)s][%(filename)s:%(lineno)s - %(funcName)13s()] %(message)s"
logging.basicConfig(format=FORMAT, stream=sys.stdout, encoding='utf-8', level=logging.DEBUG)
modelStorePath = ModelStorePath + "/generation"

def TokenizePair(data_pair, tokenizer):

  sentances = data_pair['code'].split("\n")

  for i in range(1, len(sentances)):
    sen = "\n".join(sentances[:i])
    input_text = f"Code Gen: {sen} </s>"
    target_text = f"{sentances[i]} </s>"

    encoded = tokenizer(
        input_text,
        # pad_to_max_length=True,
        padding='max_length',
        truncation=True,
        max_length=512,
        return_tensors='pt'
    )

    decoded = tokenizer(
        target_text,
        # pad_to_max_length=True,
        padding='max_length',
        truncation=True,
        max_length=512,
        return_tensors='pt'
    )

    input_ids = encoded.input_ids.flatten()
    output_ids = decoded.input_ids.flatten()

    yield {
        'input_ids': input_ids,
        'labels' : output_ids
    }

# Loading dataset
class CustomIterableDataset(torch.utils.data.IterableDataset):
    def __init__(self, file_paths, tokenizer):
        self.file_paths = file_paths
        self.tokenizer = tokenizer

    def __iter__(self):
        for file_path in self.file_paths:
            logging.debug(f"loading {file_path}")
            with open(file_path, 'r') as file:
                data = json.load(file)
                for data_pair in data:
                    for tokenizedPair in TokenizePair(data_pair, self.tokenizer):
                      tokenizedPair["file"] = file_path
                      yield tokenizedPair


logging.info("Loading model")
t5model = T5Model()

logging.info("Defining dataset")
jsons = [f"{DataStorePath}/{f}" for f in os.listdir(DataStorePath)]
train_dataset = CustomIterableDataset(jsons, t5model.tokenizer)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=1)


model = t5model.model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

logging.info("Training")
# Fine-tuning the model
num_epochs = 3
for epoch in range(num_epochs):
    for batch in train_loader:
      try:
        input_ids = batch['input_ids'].to(device)
        labels = batch['labels'].to(device)

        optimizer.zero_grad()

        outputs = model(
            input_ids=input_ids,
            labels=labels
        )

        loss = outputs.loss
        loss.backward()
        optimizer.step()

        print(f"File {batch['file']} Loss : {loss.item()}")
        logging.debug(f"File {batch['file']} Loss : {loss.item()}")
      except Exception as e:
        logging.error(e)
      except:
        logging.error("Didn't catch that")

    print(f"Epoch {epoch+1}/{num_epochs} | Loss: {loss.item()}")
    logging.info(f"Epoch {epoch+1}/{num_epochs} | Loss: {loss.item()}")

    timestamp = time.time()
    model.save_pretrained(f"{modelStorePath}/fine_tuned_model.{timestamp}")
    t5model.tokenizer.save_pretrained(f"{modelStorePath}/fine_tuned_model.{timestamp}")

logging.info("Saving")
# Save the model after training
model.save_pretrained(f"{modelStorePath}/fine_tuned_model")
t5model.tokenizer.save_pretrained(f"{modelStorePath}/fine_tuned_model")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/703k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/294k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/12.5k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/902 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# Streaming output truncated to the last 5000 lines.
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.07427261024713516
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.014675409533083439
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.023393414914608
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.02324634976685047
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.04883069172501564
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.06446563452482224
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.022862732410430908
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.1108323335647583
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.04748929664492607
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.03626523166894913
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.016289958730340004
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.043270353227853775
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.036085814237594604
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.022430825978517532
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.041842252016067505
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.036974504590034485
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.022214561700820923
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.07027257233858109
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.027798393741250038
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.012397442944347858
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.049258846789598465
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.029874242842197418
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.018985150381922722
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.02344006672501564
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.01470934972167015
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.019750604405999184
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.07655469328165054
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.017587810754776
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.032480284571647644
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.014680332504212856
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.04439667984843254
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.014687184244394302
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.0431441031396389
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.016224002465605736
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.008592065423727036
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.010902950540184975
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.055625855922698975
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.009393511340022087
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.08896778523921967
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.15768763422966003
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.027719033882021904
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.018249662593007088
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.041932910680770874
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.048023875802755356
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.14653325080871582
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.16917569935321808
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.07259932160377502
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.04382765665650368
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.020822793245315552
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.13367922604084015
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.008060174994170666
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.011165199801325798
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.01200869120657444
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.07402615994215012
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.19909657537937164
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.030296368524432182
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.019779253751039505
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0.03052973933517933
# File ['/content/drive/MyDrive/NLP-Project/data/drawing.json'] Loss : 0
inputs = input_str.split("\n")
for i in range(1,len(inputs)):
  print(finalModel.predict("Code Gen: " + "\n".join(inputs[:i])))
# Out:
# def edges(G, k, d):
# def edges(G, u, v, k, k, k, k, k, k, d):
#     if G.is_directed():
#         return 0
#         raise NetworkXError(msg)
#     return 0
#     return 0
#     return nx.utils.powerlaw_sum(G.edges, data='name'))
#     H.add_edge(0, 1, weight=1)
#     for u, v in edges:
#         peak_number = 0
#         if G.is_multigraph():
#     return peak_number
#     return H
#     return (0, 1, 'edge1'), 'edge1', 'edge2', 'edge3', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4', 'edge4

# %%
# Attempt BLEU score

import json
import os
import sys

final_model = "/content/drive/MyDrive/NLP-Project/finetuned/fine_tuned_model.1702233587.7906475"

from nltk.translate.bleu_score import corpus_bleu, SmoothingFunction


model = T5Model_Pretrained(final_model)

dataset = []

jsons = [f"{DataStorePath}/{f}" for f in os.listdir(DataStorePath)]
for js in jsons:
    if js.endswith(".json"):
        with open(js) as f:
            data = json.load(f)
            for pair in data:
                dataset.append(pair)

size = len(dataset)
print(size)
inputs = [data["code"] for data in dataset]
expected_output = [data["docstring"].split() for data in dataset]
calculated_output = []
for i,s in enumerate(inputs):
  prediction = model.predict(s).split()
  print(f"{i}/{size} : {prediction[:6]}" )
  calculated_output.append(prediction)

bleu_score = corpus_bleu(expected_output, calculated_output, smoothing_function=SmoothingFunction().method1)

print(bleu_score)
# Out:
# 2090
# 0/2090 : ['Preprocess', 'the', 'graph', 'to', 'add', 'edges']
# Token indices sequence length is longer than the specified maximum sequence length for this model (629 > 512). Running this sequence through the model will result in indexing errors
# 1/2090 : ['Estimate', 'the', 'Fiedler', 'vector', 'using', 'the']
# 2/2090 : ['Find', 'the', 'Fiedler', 'vector', 'using', 'the']
# 3/2090 : ['Returns', 'a', 'function', 'that', 'solves', 'the']
# 4/2090 : ['Returns', 'the', 'algebraic', 'connectivity', 'of', 'an']
# 5/2090 : ['Find', 'the', 'Fiedler', 'vector.', 'The', 'Fiedler']
# 6/2090 : ['Compute', 'a', 'random', 'simple', 'ordering', 'of']
# 7/2090 : ['Fiedler', 'vector', 'to', 'bisection', 'graph.', 'This']
# 8/2090 : ['Make', 'X', 'orthogonal', 'to', 'the', 'nullspace']
# 9/2090 : ['Make', 'X', 'orthogonal', 'to', 'the', 'nullspace']
# 10/2090 : ['Returns', 'a', 'function', 'that', 'returns', 'a']
# 11/2090 : ['Returns', 'a', 'function', 'that', 'returns', 'a']
# 12/2090 : ['Returns', 'a', 'numpy', 'array', 'using', 'attributes']
# 13/2090 : ['Returns', 'a', 'SciPy', 'sparse', 'array', 'using']
# 14/2090 : ['Returns', 'the', 'Bethe', 'Hessian', 'matrix', 'of']
# 15/2090 : ['Returns', 'incidence', 'matrix', 'of', 'graph', 'G.']
# 16/2090 : ['Returns', 'adjacency', 'matrix', 'of', 'graph', 'G.']
# 17/2090 : ['Returns', 'the', 'Laplacian', 'of', 'graph', '`G`.']
# 18/2090 : ['Returns', 'the', 'normalized', 'Laplacian', 'matrix', 'of']
# 19/2090 : ['Returns', 'the', 'total', 'weight', 'of', 'a']
# 20/2090 : ['Returns', 'the', 'directed', 'Laplacian', 'matrix', 'of']
# 21/2090 : ['Returns', 'the', 'directed', 'combinatorial', 'Laplacian', 'matrix']
# 22/2090 : ['Returns', 'the', 'transition', 'matrix', 'of', 'a']
# 23/2090 : ['Returns', 'the', 'modularity', 'matrix', 'of', 'a']
# 24/2090 : ['Returns', 'the', 'directed', 'modularity', 'matrix', 'of']
# 25/2090 : ['Returns', 'eigenvalues', 'of', 'the', 'Laplacian', 'of']
# 26/2090 : ['Returns', 'eigenvalues', 'of', 'the', 'normalized', 'Laplacian']
# 27/2090 : ['Returns', 'eigenvalues', 'of', 'the', 'adjacency', 'matrix']
# 28/2090 : ['Returns', 'eigenvalues', 'of', 'the', 'modularity', 'matrix']
# 29/2090 : ['Returns', 'eigenvalues', 'of', 'the', 'Bethe', 'Hessian']
# 30/2090 : ['Test', 'that', '"tracemin_chol"', 'raises', 'an', 'exception.']
# 31/2090 : ['Test', 'that', '"tracemin_chol"', 'raises', 'an', 'exception.']
# 32/2090 : ['Test', 'that', '"tracemin_chol"', 'raises', 'an', 'error.']
# 33/2090 : ['Test', 'that', '"tracemin_unknown"', 'raises', 'an', 'exception.']
# 34/2090 : ['Bethe', 'Hessian', 'matrix:', 'H', '=', 'nx.bethe_hessian_matrix(self.G,']
# 35/2090 : ['Conversion', 'to', 'incidence', 'matrix', 'to', 'incidence']
# 36/2090 : ['Conversion', 'from', 'graph', 'to', 'adjacency', 'matrix']
# 37/2090 : ['Directed', 'and', 'non-trivial', 'test', 'for', 'directed_laplacian.']
# 38/2090 : ['Tests', 'that', 'the', 'directed', 'combinatorial', 'graph']
# 39/2090 : ['Graph', '2', 'is', 'a', 'symmetric', 'graph']
# 40/2090 : ['Generalized', 'Graph,', 'not', 'a', 'sparse', 'matrix.']
# 41/2090 : ['Modularity', 'matrix', 'with', '4', 'nodes', 'and']
# 42/2090 : ['Modularity', 'matrix', 'with', 'weights']
# 43/2090 : ['Directed', 'Modularity', 'matrix', 'with', 'node', 'permutation,']
# 44/2090 : ['laplacian_spectrum(self.WG,', 'self.WG,', 'self.WG,', 'self.WG,', 'self.a_weight,', 'self.a_weight,']
# 45/2090 : ['Normalized', 'Laplacian', 'eigenvalues']
# 46/2090 : ['Adjacency', 'eigenvalues:', 'Spectrum', 'of', 'the', 'graph,']
# 47/2090 : ['Modularity', 'eigenvalues:', 'spectral', 'data,', 'must', 'be']
# 48/2090 : ['Bethe-Hessian', 'eigenvalues:', '`P`', 'should', 'be', 'a']
# 49/2090 : ['Can', 'the', 'specified', 'backend', 'run', 'this']
# 50/2090 : ['Convert', 'a', 'graph', 'to', 'one', 'specific']
# 51/2090 : ['Call', 'this', 'dispatchable', 'function', 'with', 'a']
# 52/2090 : ['Call', 'this', 'graph', 'and', 'check', 'if']
# 53/2090 : ['Allow', 'this', 'object', 'to', 'be', 'serialized']
# 54/2090 : ['Decorator', 'to', 'mark', 'algorithms', 'as', 'not']
# 55/2090 : ['Decorator', 'to', 'ensure', 'clean', 'opening', 'and']
# 56/2090 : ['Decorator', 'to', 'allow', 'user', 'to', 'specify']
# 57/2090 : ['Decorator', 'to', 'generate', 'a', 'random.RandomState', 'instance.']
# 58/2090 : ['Decorator', 'to', 'generate', 'a', 'random.RandomState', 'instance.']
# 59/2090 : ['Decorator', 'to', 'check', 'arguments', 'that', 'take']
# 60/2090 : ['Compile', 'the', 'decorated', 'decorated', 'function,', 'and']
# 61/2090 : ['Decorator', 'to', 'wrap', 'fcall3']
# 62/2090 : ['Returns', 'the', 'number', 'of', 'nodes', 'in']
# 63/2090 : ['Returns', 'a', 'short-name', 'version', 'of', 'a']
# 64/2090 : ['Compile', 'decorated', 'decorated', 'function.', 'The', 'decorated']
# 65/2090 : ['Recursively', 'assemble', 'the', 'decorated', 'function', 'wrapping']
# 66/2090 : ['Construct', 'a', 'Signature', 'object', 'describing', '`f`']
# 67/2090 : ['flattens', 'a', 'recursive', 'list', 'of', 'lists']
# 68/2090 : ['Indent', 'a', 'tree', 'of', 'lines,', 'preserving']
# 69/2090 : ['Initialize', 'a', 'new', 'key-value', 'pairs.', 'Parameters']
# 70/2090 : ['Returns', 'a', 'minimum', 'key-value', 'pair.', 'Returns']
# 71/2090 : ['Delete', 'the', 'minimum', 'pair', 'in', 'the']
# 72/2090 : ['Returns', 'the', 'value', 'associated', 'with', 'a']
# 73/2090 : ['Insert', 'a', 'new', 'key-value', 'pair', 'or']
# 74/2090 : ['Returns', 'whether', 'the', 'heap', 'if', 'empty.']
# 75/2090 : ['Returns', 'whether', 'the', 'graph', 'is', 'True']
# 76/2090 : ['Returns', 'the', 'number', 'of', 'key-value', 'pairs']
# 77/2090 : ['Returns', 'True', 'if', 'a', 'key', 'is']
# 78/2090 : ['Initialize', 'a', 'pairing', 'heap.']
# 79/2090 : ['Link', 'two', 'nodes,', 'making', 'the', 'one']
# 80/2090 : ['Merge', 'the', 'children', 'of', 'the', 'given']
# 81/2090 : ['Cut', 'a', 'node', 'from', 'its', 'parent.']
# 82/2090 : ['Create', 'a', 'binary', 'heap.']
# 83/2090 : ['Add', 'a', 'new', 'empty', 'queue.']
# 84/2090 : ['Replaced', 'the', 'original', 'heap', 'with', 'the']
# 85/2090 : ['Add', 'an', 'element', 'to', 'the', 'queue.']
# 86/2090 : ['Remove', 'and', 'return', 'a', 'single', 'element']
# 87/2090 : ['Replace', 'an', 'element', 'in', 'the', 'queue']
# 88/2090 : ['Remove', 'an', 'element', 'from', 'the', 'queue.']
# 89/2090 : ['Move', 'up', 'until', 'hitting', 'a', 'leaf.']
# 90/2090 : ['Move', 'up', 'until', 'hitting', 'a', 'certain']
# 91/2090 : ['Return', 'flattened', 'version', 'of', '(possibly', 'nested)']
# 92/2090 : ['Returns', 'list', 'of', 'integers', 'from', 'sequence']
# 93/2090 : ['Returns', 'a', 'numpy', 'array', 'or', 'dictionary']
# 94/2090 : ['Convert', 'a', 'dictionary', 'of', 'data', 'to']
# 95/2090 : ['Convert', 'a', 'dictionary', 'of', 'numbers', 'to']
# 96/2090 : ['Returns', 'an', 'arbitrary', 'element', 'of', 'an']
# 97/2090 : ['Returns', 'pairwise', '(s0,', 's1,...,', 'x_1,...,', 'x_1,...,']
# 98/2090 : ['Returns', 'a', 'dictionary', 'of', 'unique', 'items']
# 99/2090 : ['Returns', 'a', 'random', 'state', 'or', 'a']
# 100/2090 : ['Returns', 'a', 'random.RandomState', 'or', 'numpy', 'random.RandomState']
# 101/2090 : ['Returns', 'True', 'if', 'nodes', 'are', 'equal,']
# 102/2090 : ['Returns', 'True', 'if', 'edges', 'are', 'equal,']
# 103/2090 : ['Returns', 'True', 'if', 'graphs', 'are', 'equal,']
# 104/2090 : ['Returns', 'sample', 'numbers', 'in', 'powerlaw', 'degree']
# 105/2090 : ['Returns', 'a', 'random', 'value', 'chosen', 'from']
# 106/2090 : ['Returns', 'cumulative', 'cumulative', 'distribution', 'from', 'discrete']
# 107/2090 : ['Returns', 'a', 'random', 'sequence', 'of', 'the']
# 108/2090 : ['Returns', 'k', 'items', 'without', 'replacement', 'from']
# 109/2090 : ['Returns', 'a', 'single', 'sample', 'from', 'the']
# 110/2090 : ['Generate', 'an', 'ordering', '(permutation)', 'of', 'the']
# 111/2090 : ['Generate', 'an', 'ordering', '(permutation)', 'of', 'the']
# 112/2090 : ['Create', 'a', 'new', 'Graph', 'object', 'and']
# 113/2090 : ['Returns', 'a', 'path', 'to', 'the', 'given']
# 114/2090 : ['Iterate', 'over', 'the', 'members', 'of', 'this']
# 115/2090 : ['Returns', 'a', 'generator', 'of', 'sets,', 'each']
# 116/2090 : ['Find', 'the', 'sets', 'that', 'are', 'not']
# 117/2090 : ['Bad', 'because', 'it', "doesn't", 'wrap', 'the']
# 118/2090 : ['If', '`iterator`', 'is', 'an', 'iterator,', 'raises']
# 119/2090 : ['Ensure', 'objects', 'are', 'not', 'exposed', 'in']
# 120/2090 : ['Generate', 'a', 'single', 'line', 'of', 'the']
# 121/2090 : ['Write', 'the', 'graph', 'as', 'a', 'list']
# 122/2090 : ['Parse', 'lines', 'of', 'a', 'graph', 'adjacency']
# 123/2090 : ['Read', 'a', 'graph', 'in', 'adjacency', 'list']
# 124/2090 : ['Generate', 'a', 'single', 'line', 'of', 'the']
# 125/2090 : ['Write', 'a', 'bipartite', 'network', 'to', 'a']
# 126/2090 : ['Parse', 'lines', 'of', 'an', 'edge', 'list']
# 127/2090 : ['Read', 'a', 'graph', 'from', 'a', 'list']
# 128/2090 : ['Write', 'a', 'weighted', 'edgelist', 'of', 'the']
# 129/2090 : ['Returns', 'a', 'read', 'of', 'a', 'weighted']
# 130/2090 : ['Write', 'the', 'graph', 'G', 'in', 'GEXF']
# 131/2090 : ['Generate', 'lines', 'for', 'edges', 'in', 'GEXF']
# 132/2090 : ['Returns', 'a', 'NetworkX', 'graph', 'or', 'forests']
# 133/2090 : ['Relabel', 'graph', 'to', 'create', 'a', 'node']
# 134/2090 : ['Use', 'XML', 'character', 'references', 'to', 'escape']
# 135/2090 : ['Replace', 'XML', 'character', 'references', 'with', 'the']
# 136/2090 : ['Returns', 'a', 'value', 'of', 'a', 'Python']
# 137/2090 : ['Read', 'a', 'graph', 'in', 'GML', 'format']
# 138/2090 : ['Returns', 'a', 'NetworkX', 'graph', 'from', 'a']
# 139/2090 : ['Parse', 'lines', 'of', 'a', 'GML', '`lines`']
# 140/2090 : ['Returns', 'a', 'string', 'representation', 'of', 'a']
# 141/2090 : ['Returns', 'a', 'generator', 'of', 'strings', 'in']
# 142/2090 : ['Write', 'the', 'graph', 'in', 'GML', 'format']
# 143/2090 : ['Yield', 'bytes', 'in', 'the', 'graph6', 'encoding']
# 144/2090 : ['Returns', 'an', 'undirected', 'graph', 'in', 'graph6']
# 145/2090 : ['Returns', 'bytes', 'in', 'the', 'graph6', 'format']
# 146/2090 : ['Read', 'a', 'simple', 'undirected', 'graph', 'in']
# 147/2090 : ['Write', 'a', 'simple', 'undirected', 'graph', 'to']
# 148/2090 : ['Write', 'an', 'undirected', 'graph', 'to', 'the']
# 149/2090 : ['Returns', 'integer', 'number', 'from', 'networkx', 'format']
# 150/2090 : ['Returns', 'an', 'integer', 'or', 'a', 'list']
# 151/2090 : ['Returns', 'sequence', 'of', 'bits', 'from', '4-bit-per-value']
# 152/2090 : ['Write', 'the', 'graph', 'G', 'to', 'the']
# 153/2090 : ['Write', 'the', 'graph', 'in', 'GraphML', 'XML']
# 154/2090 : ['Generate', 'lines', 'for', 'the', 'graph', '`G`']
# 155/2090 : ['Returns', 'a', 'NetworkX', 'graph', 'or', 'edges']
# 156/2090 : ['Returns', 'a', 'NetworkX', 'graph', 'from', 'a']
# 157/2090 : ['Returns', 'the', 'xml', 'type', 'with', 'the']
# 158/2090 : ['Infer', 'the', 'attribute', 'types', 'of', 'data']
# 159/2090 : ['Add', 'data', 'to', 'the', 'data', 'dictionary']
# 160/2090 : ['Appends', 'attribute', 'data', 'to', 'edges', 'or']
# 161/2090 : ['Serialize', 'graph', 'G', 'to', 'GraphML', 'to']
# 162/2090 : ['Add', 'many', 'graphs', 'to', 'this', 'GraphML']
# 163/2090 : ['Serialize', 'graph', 'G', 'to', 'the', 'GraphML.']
# 164/2090 : ['Appends', 'attribute', 'data', 'to', 'xml_obj', 'with']
# 165/2090 : ['Add', 'a', 'node', 'to', 'the', 'graph.']
# 166/2090 : ['Add', 'an', 'edge', 'to', 'the', 'graph.']
# 167/2090 : ['Returns', 'the', 'data', 'elements', 'of', 'the']
# 168/2090 : ['Returns', 'a', 'dictionary', 'of', 'keys', 'and']
# 169/2090 : ['Read', 'graph', 'in', 'LEDA', 'format', 'from']
# 170/2090 : ['Parse', 'lines', 'of', 'a', 'LEDA', 'format']
# 171/2090 : ['Returns', 'a', 'generator', 'of', 'lines', 'in']
# 172/2090 : ['Write', 'a', 'multiline', 'adjacency', 'list', 'of']
# 173/2090 : ['Parse', 'lines', 'of', 'a', 'multiline', 'adjacency']
# 174/2090 : ['Read', 'a', 'multi-line', 'adjacency', 'list', 'or']
# 175/2090 : ['Write', 'NetworkX', 'graph', 'in', 'P2G', 'format']
# 176/2090 : ['Read', 'graph', 'in', 'p2g', 'format', 'from']
# 177/2090 : ['Parse', 'p2g', 'format', 'from', 'string', 'or']
# 178/2090 : ['Generate', 'lines', 'in', 'Pajek', 'graph', 'format.']
# 179/2090 : ['Write', 'the', 'graph', 'as', 'Pajek', 'format']
# 180/2090 : ['Parse', 'Pajek', 'format', 'graph', 'from', 'path.']
# 181/2090 : ['Parse', 'Pajek', 'format', 'graph', 'from', 'string']
# 182/2090 : ['Returns', 'a', 'string', 'representation', 'of', 't.']
# 183/2090 : ['Yields', 'bytes', 'in', 'the', 'sparse6', 'encoding']
# 184/2090 : ['Returns', 'an', 'undirected', 'graph', 'or', 'multigraph']
# 185/2090 : ['Returns', 'bytes', 'in', 'the', 'sparse6', 'format']
# 186/2090 : ['Read', 'an', 'undirected', 'graph', 'in', 'the']
# 187/2090 : ['Write', 'an', 'undirected', 'graph', 'to', 'the']
# 188/2090 : ['Returns', '1', 'if', 'x', 'is', 'encoded']
# 189/2090 : ['Returns', 'an', 'iterator', 'over', 'the', 'data']
# 190/2090 : ['Generates', 'lines', 'in', 'a', 'network', 'text']
# 191/2090 : ['Creates', 'a', 'nice', 'text', 'representation', 'of']
# 192/2090 : ['Given', 'a', 'directed/undirected', 'graph,', 'returns', 'a']
# 193/2090 : ['Creates', 'a', 'nice', 'utf8', 'representation', 'of']
# 194/2090 : ['Parse', 'lines', 'of', 'a', 'network', 'text']
# 195/2090 : ['Returns', 'data', 'in', 'G', 'that', 'are']
# 196/2090 : ['Returns', 'graph', 'from', 'adjacency', 'data', 'format.']
# 197/2090 : ['Returns', 'data', 'in', 'cyjs', 'format', 'that']
# 198/2090 : ['Returns', 'a', 'NetworkX', 'graph', 'from', 'a']
# 199/2090 : ['Returns', 'a', 'tuple', 'representation', 'of', 'a']
# 200/2090 : ['Returns', 'data', 'in', 'node-link', 'format', 'that']
# 201/2090 : ['Returns', 'graph', 'from', 'node-link', 'data', 'format.']
# 202/2090 : ['Returns', 'data', 'in', 'a', 'tree', 'format']
# 203/2090 : ['Returns', 'graph', 'from', 'tree', 'data', 'format.']
# 204/2090 : ['Test', 'for', 'reading', 'many', 'graphs', 'from']
# 205/2090 : ['Test', 'that', 'a', 'detailed', 'exception', 'is']
# 206/2090 : ['Test', 'that', 'a', 'detailed', 'exception', 'is']
# 207/2090 : ['Test', 'that', 'a', 'detailed', 'exception', 'is']
# 208/2090 : ['Test', 'that', 'data', 'and', 'keys', 'of']
# 209/2090 : ['Writing', 'keys', 'to', 'the', 'temp', 'file']
# 210/2090 : ['When', 'sources', 'are', 'specified,', 'we', 'should']
# 211/2090 : ['Walk', 'through', 'the', 'cases', 'going', 'from']
